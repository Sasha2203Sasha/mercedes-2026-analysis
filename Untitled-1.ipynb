# %%
import fastf1 as ff1
import pandas as pd
import logging

# Показываем логи, чтобы видеть процесс загрузки
logging.basicConfig(level=logging.INFO)

# Включаем кэш в папку data
ff1.Cache.enable_cache('data/')
print("✅ Кэш включён в папку data/")
# Out:
# ✅ Кэш включён в папку data/

# %%
import fastf1 as ff1

# Включаем кэш
ff1.Cache.enable_cache('data/')

# Тест: одна гонка
print("Пробую загрузить Гран-при Испании 2026...")
session = ff1.get_session(2026, 'Spanish Grand Prix', 'R')
session.load()

# Показываем, кто есть в результатах
print("\nУчастники гонки (первые 10):")
print(session.results[['Abbreviation', 'TeamName']].head(10))
# Out:
# Пробую загрузить Гран-при Испании 2026...
# core           INFO 	Loading data for Spanish Grand Prix - Race [v3.8.3]
# INFO:fastf1.fastf1.core:Loading data for Spanish Grand Prix - Race [v3.8.3]
# req            INFO 	No cached data found for session_info. Loading data...
# INFO:fastf1.fastf1.req:No cached data found for session_info. Loading data...
# _api           INFO 	Fetching session info data...
# INFO:fastf1.api:Fetching session info data...
# DEBUG:fastf1.api:Falling back to livetiming mirror (https://livetiming-mirror.fastf1.dev)
# logger      WARNING 	Failed to load session info data!
# WARNING:fastf1.fastf1.core:Failed to load session info data!
# DEBUG:fastf1.fastf1.core:Traceback for failure in session info data
# Traceback (most recent call last):
#   File "C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\fastf1\logger.py", line 112, in __wrapped
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\fastf1\core.py", line 1452, in _load_session_info
#     self._session_info = api.session_info(self.api_path,
#                          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\fastf1\req.py", line 459, in _cached_api_request
#     data = func(api_path, **func_kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\fastf1\_api.py", line 1730, in session_info
#     raise SessionNotAvailableError(
# fastf1._api.SessionNotAvailableError: No data for this session! If this session only finished recently, please try again in a few minutes.
# req            INFO 	No cached data found for driver_info. Loading data...
# INFO:fastf1.fastf1.req:No cached data found for driver_info. Loading data...
# _api           INFO 	Fetching driver list...
# INFO:fastf1.api:Fetching driver list...
# DEBUG:fastf1.api:Falling back to livetiming mirror (https://livetiming-mirror.fastf1.dev)
# core        WARNING 	Failed to load extended driver information!
# WARNING:fastf1.fastf1.core:Failed to load extended driver information!
# DEBUG:fastf1.fastf1.core:Exception while loading driver list
# Traceback (most recent call last):
#   File "C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\fastf1\core.py", line 2459, in _drivers_from_f1_api
#     f1di = api.driver_info(self.api_path, livedata=livedata)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\fastf1\req.py", line 459, in _cached_api_request
#     data = func(api_path, **func_kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\fastf1\_api.py", line 1564, in driver_info
#     raise SessionNotAvailableError(
# fastf1._api.SessionNotAvailableError: No data for this session! If this session only finished recently, please try again in a few minutes.
# core        WARNING 	No result data for this session available on Ergast! (This is expected for recent sessions)
# WARNING:fastf1.fastf1.core:No result data for this session available on Ergast! (This is expected for recent sessions)
# core        WARNING 	Failed to load driver list and session results!
# WARNING:fastf1.fastf1.core:Failed to load driver list and session results!
# req            INFO 	No cached data found for session_status_data. Loading data...
# INFO:fastf1.fastf1.req:No cached data found for session_status_data. Loading data...
# _api           INFO 	Fetching session status data...
# INFO:fastf1.api:Fetching session status data...
# DEBUG:fastf1.api:Falling back to livetiming mirror (https://livetiming-mirror.fastf1.dev)
# logger      WARNING 	Failed to load session status data!
# WARNING:fastf1.fastf1.core:Failed to load session status data!
# DEBUG:fastf1.fastf1.core:Traceback for failure in session status data
# Traceback (most recent call last):
#   File "C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\fastf1\logger.py", line 112, in __wrapped
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\fastf1\core.py", line 2136, in _load_session_status_data
#     session_status = api.session_status_data(self.api_path,
#                      ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\fastf1\req.py", line 459, in _cached_api_request
#     data = func(api_path, **func_kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\fastf1\_api.py", line 1362, in session_status_data
#     raise SessionNotAvailableError(
# fastf1._api.SessionNotAvailableError: No data for this session! If this session only finished recently, please try again in a few minutes.
# req            INFO 	No cached data found for lap_count. Loading data...
# INFO:fastf1.fastf1.req:No cached data found for lap_count. Loading data...
# _api           INFO 	Fetching lap count data...
# INFO:fastf1.api:Fetching lap count data...
# DEBUG:fastf1.api:Falling back to livetiming mirror (https://livetiming-mirror.fastf1.dev)
# logger      WARNING 	Failed to load total lap count!
# WARNING:fastf1.fastf1.core:Failed to load total lap count!
# DEBUG:fastf1.fastf1.core:Traceback for failure in total lap count
# Traceback (most recent call last):
#   File "C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\fastf1\logger.py", line 112, in __wrapped
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\fastf1\core.py", line 2118, in _load_total_lap_count
#     lap_count = api.lap_count(self.api_path, livedata=livedata)
#                 ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\fastf1\req.py", line 459, in _cached_api_request
#     data = func(api_path, **func_kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\fastf1\_api.py", line 1505, in lap_count
#     raise SessionNotAvailableError(
# fastf1._api.SessionNotAvailableError: No data for this session! If this session only finished recently, please try again in a few minutes.
# req            INFO 	No cached data found for track_status_data. Loading data...
# INFO:fastf1.fastf1.req:No cached data found for track_status_data. Loading data...
# _api           INFO 	Fetching track status data...
# INFO:fastf1.api:Fetching track status data...
# DEBUG:fastf1.api:Falling back to livetiming mirror (https://livetiming-mirror.fastf1.dev)
# logger      WARNING 	Failed to load track status data!
# WARNING:fastf1.fastf1.core:Failed to load track status data!
# DEBUG:fastf1.fastf1.core:Traceback for failure in track status data
# Traceback (most recent call last):
#   File "C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\fastf1\logger.py", line 112, in __wrapped
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\fastf1\core.py", line 2105, in _load_track_status_data
#     track_status = api.track_status_data(self.api_path, livedata=livedata)
#                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\fastf1\req.py", line 459, in _cached_api_request
#     data = func(api_path, **func_kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\fastf1\_api.py", line 1306, in track_status_data
#     raise SessionNotAvailableError(
# fastf1._api.SessionNotAvailableError: No data for this session! If this session only finished recently, please try again in a few minutes.
# req            INFO 	No cached data found for _extended_timing_data. Loading data...
# INFO:fastf1.fastf1.req:No cached data found for _extended_timing_data. Loading data...
# _api           INFO 	Fetching timing data...
# INFO:fastf1.api:Fetching timing data...
# DEBUG:fastf1.api:Falling back to livetiming mirror (https://livetiming-mirror.fastf1.dev)
# logger      WARNING 	Failed to load timing data!
# WARNING:fastf1.fastf1.core:Failed to load timing data!
# DEBUG:fastf1.fastf1.core:Traceback for failure in lap timing data
# Traceback (most recent call last):
#   File "C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\fastf1\logger.py", line 112, in __wrapped
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\fastf1\core.py", line 1458, in _load_laps_data
#     = api._extended_timing_data(self.api_path, livedata=livedata)
#       ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\fastf1\req.py", line 459, in _cached_api_request
#     data = func(api_path, **func_kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\fastf1\_api.py", line 201, in _extended_timing_data
#     raise SessionNotAvailableError(
# fastf1._api.SessionNotAvailableError: No data for this session! If this session only finished recently, please try again in a few minutes.
# core        WARNING 	Cannot load lap times for first lap from Ergast. Timing data is not available for this session.
# WARNING:fastf1.fastf1.core:Cannot load lap times for first lap from Ergast. Timing data is not available for this session.
# req            INFO 	No cached data found for car_data. Loading data...
# INFO:fastf1.fastf1.req:No cached data found for car_data. Loading data...
# _api           INFO 	Fetching car data...
# INFO:fastf1.api:Fetching car data...
# DEBUG:fastf1.api:Falling back to livetiming mirror (https://livetiming-mirror.fastf1.dev)
# core        WARNING 	Car telemetry data is unavailable!
# WARNING:fastf1.fastf1.core:Car telemetry data is unavailable!
# req            INFO 	No cached data found for position_data. Loading data...
# INFO:fastf1.fastf1.req:No cached data found for position_data. Loading data...
# _api           INFO 	Fetching position data...
# INFO:fastf1.api:Fetching position data...
# DEBUG:fastf1.api:Falling back to livetiming mirror (https://livetiming-mirror.fastf1.dev)
# core        WARNING 	Car position data is unavailable!
# WARNING:fastf1.fastf1.core:Car position data is unavailable!
# core        WARNING 	Failed to determine `Session.t0_date`!
# WARNING:fastf1.fastf1.core:Failed to determine `Session.t0_date`!
# req            INFO 	No cached data found for weather_data. Loading data...
# INFO:fastf1.fastf1.req:No cached data found for weather_data. Loading data...
# _api           INFO 	Fetching weather data...
# INFO:fastf1.api:Fetching weather data...
# DEBUG:fastf1.api:Falling back to livetiming mirror (https://livetiming-mirror.fastf1.dev)
# logger      WARNING 	Failed to load weather data!
# WARNING:fastf1.fastf1.core:Failed to load weather data!
# DEBUG:fastf1.fastf1.core:Traceback for failure in weather data
# Traceback (most recent call last):
#   File "C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\fastf1\logger.py", line 112, in __wrapped
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\fastf1\core.py", line 2611, in _load_weather_data
#     weather_data = api.weather_data(self.api_path, livedata=livedata)
#                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\fastf1\req.py", line 459, in _cached_api_request
#     data = func(api_path, **func_kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\fastf1\_api.py", line 1656, in weather_data
#     raise SessionNotAvailableError(
# fastf1._api.SessionNotAvailableError: No data for this session! If this session only finished recently, please try again in a few minutes.
# req            INFO 	No cached data found for race_control_messages. Loading data...
# INFO:fastf1.fastf1.req:No cached data found for race_control_messages. Loading data...
# _api           INFO 	Fetching race control messages...
# INFO:fastf1.api:Fetching race control messages...
# DEBUG:fastf1.api:Falling back to livetiming mirror (https://livetiming-mirror.fastf1.dev)
# logger      WARNING 	Failed to load race control messages!
# WARNING:fastf1.fastf1.core:Failed to load race control messages!
# DEBUG:fastf1.fastf1.core:Traceback for failure in race control messages
# Traceback (most recent call last):
#   File "C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\fastf1\logger.py", line 112, in __wrapped
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\fastf1\core.py", line 2618, in _load_race_control_messages
#     race_control_messages = api.race_control_messages(self.api_path,
#                             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\fastf1\req.py", line 459, in _cached_api_request
#     data = func(api_path, **func_kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\fastf1\_api.py", line 1433, in race_control_messages
#     raise SessionNotAvailableError(
# fastf1._api.SessionNotAvailableError: No data for this session! If this session only finished recently, please try again in a few minutes.
# core           INFO 	Finished loading data for 0 drivers: []
# INFO:fastf1.fastf1.core:Finished loading data for 0 drivers: []
# Участники гонки (первые 10):
# Empty DataFrame
# Columns: [Abbreviation, TeamName]
# Index: []

# %%
import fastf1 as ff1
ff1.Cache.enable_cache('data/')

print("Загружаю расписание сезона-2026...\n")
schedule = ff1.get_event_schedule(2026)

print(f"✅ Всего этапов в календаре: {len(schedule)}\n")
print("Полный список:")
for i, row in schedule.iterrows():
    print(f" {row['EventName']} — {row['EventDate'].strftime('%d.%m.%Y')}")
# Out:
# Загружаю расписание сезона-2026...
#
# ✅ Всего этапов в календаре: 24
#
# Полный список:
#  Pre-Season Testing — 13.02.2026
#  Pre-Season Testing — 20.02.2026
#  Australian Grand Prix — 08.03.2026
#  Chinese Grand Prix — 15.03.2026
#  Japanese Grand Prix — 29.03.2026
#  Miami Grand Prix — 03.05.2026
#  Canadian Grand Prix — 24.05.2026
#  Monaco Grand Prix — 07.06.2026
#  Barcelona Grand Prix — 14.06.2026
#  Austrian Grand Prix — 28.06.2026
#  British Grand Prix — 05.07.2026
#  Belgian Grand Prix — 19.07.2026
#  Hungarian Grand Prix — 26.07.2026
#  Dutch Grand Prix — 23.08.2026
#  Italian Grand Prix — 06.09.2026
#  Spanish Grand Prix — 13.09.2026
#  Azerbaijan Grand Prix — 26.09.2026
#  Singapore Grand Prix — 11.10.2026
#  United States Grand Prix — 25.10.2026
#  Mexico City Grand Prix — 01.11.2026
#  São Paulo Grand Prix — 08.11.2026
#  Las Vegas Grand Prix — 21.11.2026
#  Qatar Grand Prix — 29.11.2026
#  Abu Dhabi Grand Prix — 06.12.2026

# %%
def clean_laps(df):
    df['LapTime_sec'] = df['LapTime'].dt.total_seconds()
    df = df[(df['LapTime_sec'] > 55) & (df['LapTime_sec'] < 150)]
    df = df[df['PitInTime'].isna() & df['PitOutTime'].isna()]
    if 'TrackStatus' in df.columns:
        df = df[df['TrackStatus'] == '1']
        df = df[df['LapNumber'] > 1]
    return df

df_clean = clean_laps(df_raw)
print(f"✅ После очистки: {len(df_clean)} кругов (было {len(df_raw)})")
print(f"🏁 Гонок: {len(df_clean['RaceName'].unique())}")
print(f"👤 Пилоты: {df_clean['Driver'].unique()}")
# Out:
# ✅ После очистки: 808 кругов (было 972)
# 🏁 Гонок: 8
# 👤 Пилоты: ['RUS' 'ANT']

# %%
import matplotlib.pyplot as plt
import numpy as np

plt.style.use('dark_background')

# Получаем список пилотов
drivers = df_clean['Driver'].unique()

# Собираем данные, убирая NaN
data = []
valid_drivers = []
for d in drivers:
    times = df_clean[df_clean['Driver'] == d]['LapTime_sec'].dropna().values
    if len(times) > 0:
        data.append(times)
        valid_drivers.append(d)

print(f"Пилоты с данными: {valid_drivers}")
print(f"Количество кругов: {[len(d) for d in data]}")

fig, ax = plt.subplots(figsize=(10, 6))

bp = ax.boxplot(data, patch_artist=True,
boxprops=dict(facecolor='#00D2BE', alpha=0.8),
medianprops=dict(color='white', linewidth=2.5),
whiskerprops=dict(color='white'),
capprops=dict(color='white'))

# Ставим подписи отдельно (вместо labels=)
ax.set_xticklabels(valid_drivers, fontsize=12)

ax.set_ylabel('Время круга (секунды)', fontsize=12)
ax.set_title('Гоночный темп: Рассел vs Антонелли\nMercedes-AMG, первые 8 этапов 2026',
fontsize=14, fontweight='bold')
ax.grid(axis='y', alpha=0.2)

# Подписываем медианы
for i, d in enumerate(data):
    med = np.median(d)
    ax.text(i + 1, med + 0.3, f'{med:.1f}с', ha='center', fontsize=10, color='#00D2BE')

plt.tight_layout()
plt.savefig('outputs/race_pace_2026.png', dpi=150, bbox_inches='tight')
plt.show()
print("✅ Готово")
# Out:
# Пилоты с данными: ['RUS', 'ANT']
# Количество кругов: [386, 422]
# ✅ Готово

# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

# --- Шаг 1: Загружаем очищенные данные (если df_clean тоже потерялась — из CSV) ---
try:
    df_clean
except NameError:
    df_raw = pd.read_csv('outputs/mercedes_2026_raw.csv')
    df_raw['LapTime'] = pd.to_timedelta(df_raw['LapTime'])
    df_raw['LapTime_sec'] = df_raw['LapTime'].dt.total_seconds()
    df_clean = df_raw[(df_raw['LapTime_sec'] > 55) & (df_raw['LapTime_sec'] < 150)]
    df_clean = df_clean[df_clean['PitInTime'].isna() & df_clean['PitOutTime'].isna()]
    if 'TrackStatus' in df_clean.columns:
        df_clean = df_clean[df_clean['TrackStatus'] == '1']
        df_clean = df_clean[df_clean['LapNumber'] > 1]
    print("✅ df_clean загружен из CSV")

# --- Шаг 2: Считаем деградацию ---
def calc_degradation(stint_laps):
    if len(stint_laps) < 5:
        return None
    X = stint_laps['TyreLife'].values.reshape(-1, 1)
    y = stint_laps['LapTime_sec'].values
    model = LinearRegression().fit(X, y)
    return model.coef_[0]

deg_results = []
for (race, driver, compound), group in df_clean.groupby(['RaceName', 'Driver', 'Compound']):
    rate = calc_degradation(group)
    if rate is not None:
        deg_results.append({
        'Race': race,
        'Driver': driver,
        'Compound': compound,
        'DegradationRate': round(rate, 4),
        'LapsInStint': len(group)
})

deg_df = pd.DataFrame(deg_results)
deg_df.to_csv('outputs/degradation_rates_2026.csv', index=False)
print(f"✅ deg_df создан и сохранён: {len(deg_df)} отрезков")

# --- Шаг 3: График ---
avg_deg = deg_df.groupby(['Driver', 'Compound'])['DegradationRate'].mean().unstack()

fig, ax = plt.subplots(figsize=(10, 6))
colors = ['#E6002B', '#FFD700', '#FFFFFF']
avg_deg.plot(kind='bar', ax=ax, color=colors[:len(avg_deg.columns)])

ax.set_ylabel('Деградация (сек/круг)', fontsize=12)
ax.set_title('Деградация шин: Рассел vs Антонелли\nMercedes-AMG, 8 этапов 2026',
fontsize=14, fontweight='bold')
ax.legend(title='Состав шин')
ax.grid(axis='y', alpha=0.2)
plt.xticks(rotation=0)

for container in ax.containers:
    ax.bar_label(container, fmt='%.3f', fontsize=9)

plt.tight_layout()
plt.savefig('outputs/degradation_2026.png', dpi=150)
plt.show()

# --- Шаг 4: Вывод ---
rus = deg_df[deg_df['Driver'] == 'RUS']['DegradationRate'].mean()
ant = deg_df[deg_df['Driver'] == 'ANT']['DegradationRate'].mean()
diff = rus - ant
better = "Рассел" if rus < ant else "Антонелли"

print(f"""
═══════════════════════════════════════
ИТОГИ: MERCEDES-AMG 2026 (8 этапов)
═══════════════════════════════════════

Средняя деградация шин (сек/круг):
• Рассел: {rus:.4f}
• Антонелли: {ant:.4f}

Разница: {abs(diff):.4f} сек/круг — лучше бережёт шины {better}

За 20-круговой отрезок это даёт ~{abs(diff)*20:.1f} сек преимущества.

Данные: FastF1 API (первые 8 этапов 2026)
═══════════════════════════════════════
""")
# Out:
# ✅ deg_df создан и сохранён: 33 отрезков
# ═══════════════════════════════════════
# ИТОГИ: MERCEDES-AMG 2026 (8 этапов)
# ═══════════════════════════════════════
#
# Средняя деградация шин (сек/круг):
# • Рассел: -0.0101
# • Антонелли: -0.0349
#
# Разница: 0.0248 сек/круг — лучше бережёт шины Антонелли
#
# За 20-круговой отрезок это даёт ~0.5 сек преимущества.
#
# Данные: FastF1 API (первые 8 этапов 2026)
# ═══════════════════════════════════════
